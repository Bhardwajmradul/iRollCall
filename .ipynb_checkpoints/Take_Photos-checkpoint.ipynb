# %%
def take_photos(n=50,name="ayushi"):
    import os
    import glob
    from PIL import Image
    import face_recognition
    import cv2
    from timeit import default_timer as timer
    from pathlib import Path
    import time
    from retinaface import RetinaFace
    from math import ceil
    image_dir=Path(f"data/train/{name}")
    if image_dir.is_dir():
        print("Photos folder is present")
    else:
        print("photos folder not found so creating one")
        image_dir.mkdir(parents=True)
    i=1
    cap=cv2.VideoCapture(0)
    while True:
        time.sleep(0.1)
        res,img=cap.read()
        print(f"Taking image{i}")
        try:
            face_locations = face_recognition.face_locations(img)
            top, right, bottom, left = face_locations[0]
            face_image = img[top:bottom, left:right]
            cv2.imwrite(f"data/train/{name}/image{i}.jpg",face_image)
            print(f"Saving image{i}")
        except IndexError as e:
            try:
                o = RetinaFace.detect_faces(img)
                coordinates=o["face_1"]["facial_area"]
                x,y,w,h=coordinates
                imgf=img[y:h, x:w]
                cv2.imwrite(f"data/test/{name}/image{i}.jpg",imgf)
                print(f"Saving image{i}")
            except Exception as e:
                print("No face found using RetinaFace. Skipping this image.")
                i=i-1
        i+=1
        if i==n+1:
            i=1
            image_dir=Path(f"data/test/{name}")
            if image_dir.is_dir():
                print("Photos folder is present")
            else:
                print("photos folder not found so creating one")
                image_dir.mkdir(parents=True)
            while True:
                time.sleep(0.1)
                res,img=cap.read()
                print(f"Taking image{i}")
                try:
                    face_locations = face_recognition.face_locations(img)
                    top, right, bottom, left = face_locations[0]
                    face_image = img[top:bottom, left:right]
                    cv2.imwrite(f"data/test/{name}/image{i}.jpg",face_image)
                    print(f"Saving image{i}")
                except IndexError as e:
                    try:
                        o = RetinaFace.detect_faces(img)
                        coordinates=o["face_1"]["facial_area"]
                        x,y,w,h=coordinates
                        imgf=img[y:h, x:w]
                        cv2.imwrite(f"data/test/{name}/image{i}.jpg",imgf)
                        print(f"Saving image{i}")
                    except Exception as e:
                        print("No face found using RetinaFace. Skipping this image.")
                        i=i-1
                i+=1
                if i==ceil((0.25*n))+1:
                    break
            cap.release()
            cv2.destroyAllWindows()
            break
    
def clean_photos(location):
    for file in location.glob("*"):
        file.unlink()
from timeit import default_timer as timer
start_time=timer()
if __name__=="__main__":
    name=input("Enter your name and press return ")
    take_photos(50,name)
end_time=timer()
print(end_time-start_time)
# Out:
# Enter your name and press return test
# Photos folder is present
# Taking image1
# Saving image1
# Taking image2
# Saving image2
# Taking image3
# Saving image3
# Taking image4
# Saving image4
# Taking image5
# No face found using RetinaFace. Skipping this image.
# Taking image5
# No face found using RetinaFace. Skipping this image.
# Taking image5
# No face found using RetinaFace. Skipping this image.
# Taking image5
# No face found using RetinaFace. Skipping this image.
# Taking image5
# Saving image5
# Taking image6
# Saving image6
# Taking image7
# Saving image7
# Taking image8
# Saving image8
# Taking image9
# Saving image9
# Taking image10
# Saving image10
# Taking image11
# No face found using RetinaFace. Skipping this image.
# Taking image11
# No face found using RetinaFace. Skipping this image.
# Taking image11
# Saving image11
# Taking image12
# Saving image12
# Taking image13
# Saving image13
# Taking image14
# Saving image14
# Taking image15
# Saving image15
# Taking image16
# Saving image16
# Taking image17
# Saving image17
# Taking image18
# Saving image18
# Taking image19
# Saving image19
# Taking image20
# Saving image20
# Taking image21
# Saving image21
# Taking image22
# Saving image22
# Taking image23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 86
#      84 if __name__=="__main__":
#      85     name=input("Enter your name and press return ")
# ---> 86     take_photos(50,name)
#      87 end_time=timer()
#      88 print(end_time-start_time)
#
# Cell In[5], line 25, in take_photos(n, name)
#      23 print(f"Taking image{i}")
#      24 try:
# ---> 25     face_locations = face_recognition.face_locations(img)
#      26     top, right, bottom, left = face_locations[0]
#      27     face_image = img[top:bottom, left:right]
#
# File ~/anaconda3/lib/python3.11/site-packages/face_recognition/api.py:121, in face_locations(img, number_of_times_to_upsample, model)
#     119     return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     120 else:
# --> 121     return [_trim_css_to_bounds(_rect_to_css(face), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, model)]
#
# File ~/anaconda3/lib/python3.11/site-packages/face_recognition/api.py:105, in _raw_face_locations(img, number_of_times_to_upsample, model)
#     103     return cnn_face_detector(img, number_of_times_to_upsample)
#     104 else:
# --> 105     return face_detector(img, number_of_times_to_upsample)
#
# KeyboardInterrupt:
